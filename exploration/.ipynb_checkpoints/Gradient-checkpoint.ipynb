# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import datetime
# %matplotlib notebook

# %%
path = Path('../data')
for f in path.iterdir():
    print(f)
# Out:
# ../data/README.md
# ../data/trades.csv
# ../data/market_data.csv

# %%
market = pd.read_csv(path/'market_data.csv', index_col='Timestamp', parse_dates=True)
trades = pd.read_csv(path/'trades.csv', index_col='Timestamp', parse_dates = True)

# %%
# %matplotlib notebook
index = slice(0,2000)
instrument = 'SP-FUTURE'
plt.figure()
ax1 = plt.subplot(2,1,1)
dat_market = market[market['Instrument'] == instrument][index]
dat_trades = trades[trades['Traded Instrument'] ==instrument][index]
plt.plot(dat_market.index[index],dat_market['Bid Price'][index].rolling('1s').mean(), label="Verkoop prijs")
plt.plot(dat_market.index[index],dat_market['Ask Price'][index].rolling('1s').mean(), label ="Aankoop prijs")
plt.legend()



for t in ["BID","ASK"]:
    dat = dat_trades[dat_trades['Traded Side'] == t]
    plt.scatter(dat.index, dat['Traded Price'], label =t, s = dat['Traded Volume']/10)
    
dat_market = market[market['Instrument'] == instrument][index]
dat_trades = trades[trades['Traded Instrument'] ==instrument][index]
ax2 = plt.subplot(2,1,2,sharex=ax1)
ax2.plot(dat_market.index[index],dat_market['Bid Volume'][index], '--', label="Aanbod markt")
ax2.plot(dat_market.index[index],dat_market['Ask Volume'][index],'--', label ="Vraag markt")
for t in ["BID","ASK"]:
    dat = dat_trades[dat_trades['Traded Side'] == t]
    ax2.scatter(dat.index, dat['Traded Volume'])
plt.legend()
plt.title("Price")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Price')

# %%
index = slice(0,50)
instrument = 'SP-FUTURE'

plt.figure()
dat_market = market[market['Instrument'] == instrument][index]
dat_trades = trades[trades['Traded Instrument'] ==instrument][index]
plt.plot(dat_market.index[index],dat_market['Bid Volume'][index], label="bid")
plt.plot(dat_market.index[index],dat_market['Ask Volume'][index], label ="Ask")
for t in ["BID","ASK"]:
    dat = dat_trades[dat_trades['Traded Side'] == t]
    plt.scatter(dat.index, dat['Traded Volume'], label =t)
plt.title("Volume")
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
trades[trades['Traded Instrument']=='SP-FUTURE'][:10]
# Out:
#                     Traded Instrument Traded Side  Traded Price  Traded Volume
# Timestamp
# 2019-05-11 11:43:08         SP-FUTURE         ASK       2912.00             36
# 2019-05-11 11:43:09         SP-FUTURE         ASK       2912.75            279
# 2019-05-11 11:43:10         SP-FUTURE         ASK       2912.75            154
# 2019-05-11 11:43:11         SP-FUTURE         BID       2912.25             38
# 2019-05-11 11:43:12         SP-FUTURE         ASK       2912.50              7
# 2019-05-11 11:43:14         SP-FUTURE         BID       2912.00            256
# 2019-05-11 11:43:15         SP-FUTURE         BID       2911.75            306
# 2019-05-11 11:43:16         SP-FUTURE         BID       2911.75            291
# 2019-05-11 11:43:16         SP-FUTURE         BID       2911.50            296
# 2019-05-11 11:43:17         SP-FUTURE         BID       2911.50            444

# %%
market[market['Instrument']=='SP-FUTURE'][:10]
# Out:
#                     Instrument  Bid Price  Bid Volume  Ask Price  Ask Volume
# Timestamp
# 2019-05-11 11:43:08  SP-FUTURE    2912.25        1439    2912.50         130
# 2019-05-11 11:43:09  SP-FUTURE    2912.50        1191    2912.75         378
# 2019-05-11 11:43:10  SP-FUTURE    2912.25        1249    2912.50         320
# 2019-05-11 11:43:11  SP-FUTURE    2912.25         407    2912.50        1162
# 2019-05-11 11:43:13  SP-FUTURE    2912.00         738    2912.25         831
# 2019-05-11 11:43:14  SP-FUTURE    2911.75         871    2912.00         698
# 2019-05-11 11:43:15  SP-FUTURE    2911.75         438    2912.00        1131
# 2019-05-11 11:43:16  SP-FUTURE    2911.50        1032    2911.75         537
# 2019-05-11 11:43:17  SP-FUTURE    2911.50        1033    2911.75         536
# 2019-05-11 11:43:17  SP-FUTURE    2911.50        1007    2911.75         562

# %%
import seaborn as sns

# %%
g = sns.pairplot(market[market['Instrument'] == 'SP-FUTURE'])
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.figure()
plt.hist(market[market['Instrument'] == 'ESX-FUTURE']['Bid Volume']+ market[market['Instrument'] == 'ESX-FUTURE']['Ask Volume'])
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([ 385., 4451.,    0.,    8.,    0.,  625., 1028.,    0., 2618.,
#         1922.]),
#  array([3473. , 3474.2, 3475.4, 3476.6, 3477.8, 3479. , 3480.2, 3481.4,
#         3482.6, 3483.8, 3485. ]),
#  <a list of 10 Patch objects>)

# %%
# %matplotlib notebook
index = slice(0,1000000)
period = '1s'
instrument = 'SP-FUTURE'
plt.figure()
ax1 = plt.subplot(2,1,1)
dat_market = market[market['Instrument'] == instrument][index]
dat_trades = trades[trades['Traded Instrument'] ==instrument][index]
plt.plot(dat_market.index[index],dat_market['Bid Price'][index].rolling(period).mean(), label="Verkoop prijs")
plt.plot(dat_market.index[index],dat_market['Ask Price'][index].rolling(period).mean(), label ="Aankoop prijs")
for t in ["BID","ASK"]:
    dat = dat_trades[dat_trades['Traded Side'] == t]
    plt.scatter(dat.index, dat['Traded Price'], label =t, s = dat['Traded Volume']/10, alpha=0.7)

instrument = 'ESX-FUTURE'
ax2 = plt.subplot(2,1,2, sharex=ax1)
dat_market = market[market['Instrument'] == instrument][index]
dat_trades = trades[trades['Traded Instrument'] ==instrument][index]
ax2.plot(dat_market.index[index],dat_market['Bid Price'][index].rolling(period).mean(), label="Verkoop prijs")
ax2.plot(dat_market.index[index],dat_market['Ask Price'][index].rolling(period).mean(), label ="Aankoop prijs")
for t in ["BID","ASK"]:
    dat = dat_trades[dat_trades['Traded Side'] == t]
    ax2.scatter(dat.index, dat['Traded Price'], label =t, s = dat['Traded Volume']/10, alpha=0.7)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import scipy

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-a46d6097c53c> in <module>
# ----> 1 scipy.signal.correlate(dat_market.index[index],market[market['Instrument'] == 'SP-FUTURE']['Bid Price'][index].rolling('30s').mean(),dat_market.index[index], dat_market['Bid Price'][index].rolling('30s').mean())
#
# /usr/local/lib/python3.6/dist-packages/scipy/signal/signaltools.py in correlate(in1, in2, mode, method)
#     214     # Don't use _valfrommode, since correlate should not accept numeric modes
#     215     try:
# --> 216         val = _modedict[mode]
#     217     except KeyError:
#     218         raise ValueError("Acceptable mode flags are 'valid',"
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in __hash__(self)
#    3932
#    3933     def __hash__(self):
# -> 3934         raise TypeError("unhashable type: %r" % type(self).__name__)
#    3935
#    3936     def __setitem__(self, key, value):
#
# TypeError: unhashable type: 'DatetimeIndex'

# %%
plt.figure()
plt.plot(np.correlate(market[market['Instrument'] == "ESX-FUTURE"]['Bid Price'][0:10000],market[market['Instrument'] == "SP-FUTURE"]['Bid Price'][0:10000]))
# Out:
# <img src="data:image/png;base64,..." width="640">
